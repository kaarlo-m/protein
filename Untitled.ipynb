# %%
Python import py3Dmol view = py3Dmol.view(query='pdb:1ubq') view.setStyle({'cartoon':{'color':'spectrum'}}) view
# Out:
#   Cell In[1], line 1
#     Python import py3Dmol view = py3Dmol.view(query='pdb:1ubq') view.setStyle({'cartoon':{'color':'spectrum'}}) view
#            ^
# SyntaxError: invalid syntax

# %%
import py3Dmol 
view = py3Dmol.view()
view.addModel('pdb:16pk_A_analysis/16pk_A.pdb','xyz',{'vibrate': {'frames':10,'amplitude':1}}, viewer=(0,0))
view.setStyle({'cartoon':{'color':'spectrum'}}) 
view
# Out:
# <div id="3dmolviewer_176202350009176"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_176202350009176" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.3/build/3Dmol-min.js');
# }
#
# var viewer_176202350009176 = null;
# var warn = document.getElementById("3dmolwarning_176202350009176");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_176202350009176 = $3Dmol.createViewer(document.getElementById("3dmolviewer_176202350009176"),{backgroundColor:"white"});
# viewer_176202350009176.zoomTo();
# 	viewer_176202350009176.addModel("pdb:16pk_A_analysis/16pk_A.pdb","xyz",{"vibrate": {"frames": 10, "amplitude": 1}});
# 	viewer_176202350009176.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_176202350009176.render();
# });
# </script>
