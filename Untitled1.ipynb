# %%
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import PSF, DCD
import nglview as nv

# Load simulation results with a single line
u = mda.Universe(PSF, DCD)

# Select atoms
ag = u.select_atoms('protein')

# Atom data made available as Numpy arrays
pos=ag.positions
#ag.velocities
#ag.forces

# Iterate through trajectories
for ts in u.trajectory:
    print(ag.center_of_mass())

view=nv.show_mdanalysis(ag)
view
# Out:
# c:\Users\Kaarlo\protein\.venv\Lib\site-packages\MDAnalysis\coordinates\DCD.py:171: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# [-0.01094035  0.05727601 -0.12885778]
# [-0.01058805  0.05570178 -0.09139681]
# [ 0.00588297  0.05695601 -0.10550808]
# [-0.02685411  0.06707425 -0.15176171]
# [-0.02179312  0.08864697 -0.11737134]
# [-0.04207859  0.07922634 -0.10121021]
# [-0.08141114  0.0936705  -0.09966523]
# [-0.1039361   0.09109711 -0.06667415]
# [-0.14261582  0.03773413 -0.04117398]
# [-0.17761626  0.01610325  0.00408359]
# [-0.21185216  0.01010695 -0.02507193]
# [-0.24021555  0.03491332 -0.08879366]
# [-0.26499587 -0.00357245 -0.08283655]
# [-0.22978597  0.0134452  -0.05295084]
# [-0.28015883 -0.02846766 -0.07166099]
# [-0.28772465 -0.05448231 -0.09714094]
# [-0.30036033 -0.05482063 -0.09358487]
# [-0.32027977 -0.0771694  -0.11564494]
# [-0.31703787 -0.06171745 -0.07449886]
# [-0.33393954 -0.07421501 -0.0611818 ]
# [-0.35669304 -0.10011081 -0.0147785 ]
# [-0.34248352 -0.08265917  0.02894418]
# [-0.32944075 -0.08895409  0.0437848 ]
# [-0.33551835 -0.06470064  0.07313382]
# [-0.33381446 -0.0082567   0.10366704]
# [-0.32325378 -0.01836801  0.09488982]
# [-0.32657444  0.03386949  0.10549862]
# [-0.29604724 -0.00580879  0.09449053]
# [-0.30793692 -0.03086145  0.09430467]
# [-0.31230531 -0.02232592  0.13933666]
# [-0.34683607 -0.05411031  0.18288399]
# [-0.31320964 -0.03787415  0.20896811]
# [-0.29857486 -0.02758117  0.23253806]
# [-0.27838823 -0.05961975  0.26379623]
# [-0.22618427 -0.09589175  0.2744795 ]
# [-0.22646525 -0.11430645  0.31626944]
# [-0.23484761 -0.05773915  0.35723105]
# [-0.18895912 -0.08271818  0.3752422 ]
# [-0.15404251 -0.06227241  0.38196272]
# [-0.13418906 -0.06958208  0.40919861]
# [-0.15160969 -0.02902163  0.41363869]
# [-0.16446519 -0.0294435   0.37339175]
# [-0.21049191 -0.03981565  0.39614918]
# [-0.15660053 -0.07215405  0.39822891]
# [-0.1633305  -0.08438877  0.38888165]
# [-0.15222335 -0.09817733  0.39194546]
# [-0.17951105 -0.09563018  0.42559432]
# [-0.18294369 -0.13976285  0.40082053]
# [-0.17948964 -0.12312274  0.45176909]
# [-0.15186426 -0.15502846  0.45768285]
# [-0.12702382 -0.14681093  0.46771756]
# [-0.15476748 -0.13314407  0.53837056]
# [-0.13705491 -0.10442354  0.4865666 ]
# [-0.18285983 -0.12563254  0.45137354]
# [-0.14982479 -0.15224192  0.43654058]
# [-0.16081394 -0.1665583   0.40874975]
# [-0.12288241 -0.19938     0.39685831]
# [-0.1503536  -0.22725953  0.38836902]
# [-0.1140641  -0.25514205  0.34936506]
# [-0.13415432 -0.28603633  0.3453033 ]
# [-0.12293721 -0.2924533   0.29843069]
# [-0.12101476 -0.27118851  0.24939022]
# [-0.10489189 -0.23971669  0.20861182]
# [-0.11573709 -0.26742451  0.23495328]
# [-0.1119205  -0.28598256  0.18348044]
# [-0.04060816 -0.32084543  0.18172308]
# [-0.012402   -0.32028082  0.15129292]
# [-0.02241058 -0.31904291  0.10792958]
# [-0.03378922 -0.30310922  0.10934364]
# [ 0.05980373 -0.29676589  0.07370948]
# [ 0.054807   -0.27723282  0.11280663]
# [-0.02020484 -0.26328668  0.13572542]
# [-0.00076573 -0.29624363  0.09727864]
# [-0.00507926 -0.34257652  0.07546283]
# [ 0.02674952 -0.30082138  0.04083145]
# [ 0.08096747 -0.3116821   0.00241395]
# [ 0.08964114 -0.33585591  0.00648004]
# [ 0.07806496 -0.33089707  0.01253806]
# [ 0.08716308 -0.33350847  0.02438687]
# [ 0.09699783 -0.33510015  0.04605577]
# [ 0.0985444  -0.30611198  0.04084141]
# [ 0.10897565 -0.33555361  0.04077387]
# [ 0.10798021 -0.36650644 -0.01812982]
# [ 0.08682437 -0.37180171 -0.03777671]
# [ 0.10874133 -0.4267802   0.02227011]
# [ 0.14665064 -0.506141   -0.04006556]
# [ 0.12212811 -0.50599079  0.00949284]
# [ 0.12946555 -0.47422607  0.01689695]
# [ 0.12197092 -0.47287433  0.0286301 ]
# [ 0.14362006 -0.47121996  0.068628  ]
# [ 0.17496493 -0.45615879  0.05755553]
# [ 0.1759563  -0.3795852   0.00885767]
# [ 0.1056318  -0.36944252 -0.11531489]
# [ 0.14268906 -0.29388518 -0.12678624]
# [ 0.15377553 -0.20994658 -0.08343971]
# [ 0.14556889 -0.20983475 -0.06965805]
# [ 0.20216569 -0.24080178 -0.06406456]
# [ 0.16750884 -0.22371566 -0.09163422]
# NGLWidget(max_frame=97)
# Exception in thread Thread-19 (_call):
# Traceback (most recent call last):
#   File "C:\Users\Kaarlo\AppData\Local\Programs\Python\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 788, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Kaarlo\AppData\Local\Programs\Python\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\nglview\widget.py", line 388, in _call
#     callback(self)
#     ~~~~~~~~^^^^^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\nglview\widget.py", line 1208, in callback
#     widget.send(msg)
#     ~~~~~~~~~~~^^^^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\ipywidgets\widgets\widget.py", line 667, in send
#     self._send({"method": "custom", "content": content}, buffers=buffers)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\ipywidgets\widgets\widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\comm\base_comm.py", line 144, in send
#     self.publish_msg(
#     ~~~~~~~~~~~~~~~~^
#         "comm_msg",
#         ^^^^^^^^^^^
#     ...<2 lines>...
#         buffers=buffers,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\ipykernel\comm\comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#            ~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Kaarlo\protein\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
#            ~~~~~~~~~~~~~~~~~~~~~~^^
# LookupError: <ContextVar name='shell_parent' at 0x000001E0504C6930>
